# %% [markdown]
# Här tänker jag göra ett script för att summera försäljning för olika datum på ett år eller en månad.
# scriptet läggs sen ut på en dataframe och på så sätt kan jag göra diagram för en vecka, månad eller år.
