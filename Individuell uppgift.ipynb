# %% [markdown]
# DEL 1
#
# - 1.1

# %%
import pandas as pd

# %%
data = "C:/VScode projects/Lektion1/agent_data.csv"
#sökväg till filen

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#                             Prompt_ ID_           Timestamp_  \
# 0  20fdb890-8d9e-11f0-b4d9-0a623090504c  2024-01-01 08:00:00
# 1  2f2be192-8d9e-11f0-bc2c-0a623090504c  2024-01-01 08:00:02
# 2  2a854025-8d9e-11f0-b7fc-0a623090504c  2024-01-01 08:00:03
# 3  309ae819-8d9e-11f0-9fa6-0a623090504c  2024-01-01 08:00:05
# 4  24d71ab2-8d9e-11f0-87f2-0a623090504c  2024-01-01 08:00:05
#
#          Customer_ Name_ Customer_ Segment_       City_ Country_  \
# 0         Garmo Tech A/S        Consultancy  Copenhagen  Denmark
# 1  NordicAI Solutions AS            Startup        Oslo   Norway
# 2           NeuroNova AB            Startup   Stockholm   Sweden
# 3           NovaLogic AB            Startup   Stockholm   Sweden
# 4            novalogicab            Startup   Stockholm   Sweden
#
#       Agent_ Name_                             LLM_ Model_  \
# 0    agent-auditor                                orion-k4
# 1  agent-analytics                                kiwi-2.i
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563458 entries, 0 to 563457
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Prompt_ ID_            563458 non-null  object
#  1   Timestamp_             563458 non-null  object
#  2   Customer_ Name_        563458 non-null  object
#  3   Customer_ Segment_     563458 non-null  object
#  4   City_                  563458 non-null  object
#  5   Country_               563458 non-null  object
#  6   Agent_ Name_           563458 non-null  object
#  7   LLM_ Model_            563458 non-null  object
#  8   Compute_ Cost_ EUR_    563458 non-null  float64
#  9   Customer_ Price_ EUR_  563458 non-null  float64
#  10  Response_ Time_        563458 non-null  int64
#  11  Use_ Case_             518219 non-null  object
#  12  Prompt_ Length_        563458 non-null  int64
#  13  Access_ Method_        551474 non-null  object
# ...
